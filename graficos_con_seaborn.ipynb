# %% [markdown]
# <a href="https://colab.research.google.com/github/MarMastro/visualizacion_python/blob/master/graficos_con_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Visualizacion de datos con Python**

# %% [markdown]
# ### **Inmigracion Colombiana en Canada**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/inmigrantes_canada.csv')

# %%
print(df.columns)
# Out:
# Index(['Pais', 'Continente', 'Region', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', 'Total'],
#       dtype='object')

# %%
# Colocamos el indice como Pais.
# inplace = True Hacemos la modificacion en el df original.
df.set_index('Pais', inplace = True)
df
# Out:
#                   Continente            Region  1980  1981  1982  1983  1984  \
# Pais
# Afganistán              Asia       Sur de Asia    16    39    39    47    71
# Albania               Europa     Sur de Europa     1     0     0     0     0
# Argelia               África   Norte de África    80    67    71    69    63
# Samoa Americana      Oceanía         Polinesia     0     1     0     0     0
# Andorra               Europa     Sur de Europa     0     0     0     0     0
# ...                      ...               ...   ...   ...   ...   ...   ...
# Vietnam                 Asia  Sudeste Asiático  1191  1829  2162  3404  7583
# Sahara Occidental     África   Norte de África     0     0     0     0     0
# Yemen                   Asia   Asia Occidental     1     2     1     6     0
# Zambia                África   África Oriental    11    17    11     7    16
# Zimbabue              África   África Oriental    72   114   102    44    32
#
# ...

# %%
# Generamos un nuevo df que contenga los anios y la cantidad de migrantes de Colombia.
# Necesito que me genere una columna de lista con los strings.
# En range(el primer numero es inclusivo, el segundo es exclusivo).
anos = list(map(str, range(1980, 2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
# Creamos un filtro que nos permita encontrar Colombia en la variable anos.
# Para eso usamos loc.
colombia = df.loc['Colombia', anos]
colombia
# Out:
# 1980     266
# 1981     326
# 1982     360
# 1983     244
# 1984     235
# 1985     214
# 1986     257
# 1987     376
# 1988     352
# 1989     439
# 1990     614
# 1991     652
# 1992     582
# 1993     464
# 1994     375
# 1995     371
# 1996     381
# 1997     578
# 1998     929
# 1999    1306
# 2000    2259
# 2001    2965
# 2002    3283
# 2003    4318
# 2004    4566
# 2005    6424
# 2006    6535
# 2007    5357
# 2008    5452
# 2009    4652
# 2010    5218
# 2011    4366
# 2012    3741
# 2013    3631
# Name: Colombia, dtype: object

# %%
# Creamos un diccionario para trabajar los datos mas facilmente.
# To_list para crear una lista.
col_dict = { 'Año': colombia.index.tolist(),
             'Inmigrantes': colombia.values.tolist()}

# %%
# Creamos el df
df_col = pd.DataFrame(col_dict)
df_col.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         4652
# 30  2010         5218
# 31  2011         4366
# 32  2012         3741
# 33  2013         3631

# %% [markdown]
# ### **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_col['Año'], df_col['Inmigrantes'])

# %%
# xtics. Ampliamos los anos de 5 en 5 para que se vea mejor la descripcion del eje x.
# plt.show() para que no me muestre los datos de donde esta ubicado en memoria, etc
# plt.figure para darle una medida especifica al grafico.
plt.figure(figsize = (8,4))
plt.plot(df_col['Año'], df_col['Inmigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.show()

# %%
# Colocamos el titulo y los rotulos en el eje x y eje y.
# plt.show() debe ser el ultimo comando.
plt.figure(figsize = (8,4))
plt.plot(df_col['Año'], df_col['Inmigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.title('Inmigracion de colombianos a Canada')
plt.xlabel('Años')
plt.ylabel('Numero de inmigrantes')
plt.show()

# %%
# Separamos en variables el lienzo y la grafica.
# fig = figura y ax = grafica.
# subplots() en sus parametros podemos colocar valores para modificar la figura.
# setmajorlocator y multiplelocator arreglan la visualizacion de los tics (X o Y).
fig, ax = plt.subplots(figsize = (8, 4))
ax.plot(df_col['Año'], df_col['Inmigrantes'])
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigracion de colombianos a Canada\n1980-2013')
ax.set_xlabel('Años')
ax.set_ylabel('Numero de Inmigrantes')
plt.show()

# %%
# Trabajamos con boxplot para mostrar estadisticas de los datos.
# Hacemos todo el ejercicio desde el inicio.
# axs le llamamos porque trabajamos con dos variables.
# subplots(1, 2). Haremos una fila con dos graficas.
# ax[0] es un grafico y ax[1] es el otro.
# boxplot solo mide una variable. La variable que queremos medir es la cantidad
# de inmigrantes colombianos.


fig, axs = plt.subplots(1, 2, figsize = (10, 3))

axs[0].plot(df_col['Año'], df_col['Inmigrantes'])
axs[0].set_title('Inmigracion de colombianos a Canada\n1980-2013')
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Número de Inmigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

axs[1].boxplot(df_col['Inmigrantes'])
axs[1].set_title('Boxplot de la inmigración de colombianos\nhacia Canadá 1980-2013')
axs[1].set_xlabel('Colombia')
axs[1].set_ylabel('Número de Inmigrantes')
axs[1].grid()

plt.show()

# %%
# Describe, da la estadistica de los datos.
df_col.describe()
# Out:
#        Inmigrantes
# count    34.000000
# mean   2120.235294
# std    2163.761316
# min     214.000000
# 25%     372.000000
# 50%     633.000000
# 75%    4173.750000
# max    6535.000000

# %%
# Analizamos los datos de Colombia y otros paises.
# Con subplots(2, 2) creamos cuatro graficos.
# subplots.adjust para ajustar la distancia entre los gráficos.
# con el for  axs.flat iteramos en cada una de las graficas para arreglar
# los problemas de visualizacion.
# Ravel() convierte un array multidimensional en un array unidimensional.
# ymin y ymax para que todos los graficos esten iguales.

fig, axs = plt.subplots(2, 2, figsize = (10, 6))
fig.subplots_adjust(hspace = 0.5, wspace = 0.3)

axs[0, 0].plot(df.loc['Colombia', anos])
axs[0, 0].set_title('Colombia')

axs[0, 1].plot(df.loc['Brasil', anos])
axs[0, 1].set_title('Brasil')

axs[1, 0].plot(df.loc['Argentina', anos])
axs[1, 0].set_title('Argentina')

axs[1, 1].plot(df.loc['Perú', anos])
axs[1, 1].set_title('Perú')

ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set_xlabel('Año')
  ax.set_ylabel('Número de Inmigrantes')
  ax.grid()

plt.show()

# %% [markdown]
# ### **Personalizando Gráficos**

# %%
# Cambiando fontsize.
# Cambiando tick params para cambiarle el size de los ticks. (labelsize = 12)
# Movemos el titulo hacia la izquierda. (loc = 'left')
# Aumentamos el espesor de la linea del gráfico. (lw = 2.5)
# Cambiamos el grid de sólido a guiones. (linestyle = '-')
# Cambiamos el color de la linea del gráfico. (color = 'g')
fig, ax = plt.subplots(figsize = (8, 4))
ax.plot(df_col['Año'], df_col['Inmigrantes'], lw = 2.5, color = 'g')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigracion de colombianos a Canada\n1980-2013', fontsize = 18, loc = 'left')
ax.set_xlabel('Años', fontsize = 14)
ax.set_ylabel('Numero de Inmigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)
ax.grid(linestyle = '--')
plt.show()

# %%
# Trabajamos con los datos de sudamerica.
# Hacemos una query en el df original.
sudamerica = df.query('Region == "América del Sur"')
sudamerica.head(10)
# Out:
#                            Continente           Region  1980  1981  1982  \
# Pais
# Argentina  América Latina y el Caribe  América del Sur   368   426   626
# Bolivia    América Latina y el Caribe  América del Sur    44    52    42
# Brasil     América Latina y el Caribe  América del Sur   211   220   192
# Chile      América Latina y el Caribe  América del Sur  1233  1069  1078
# Colombia   América Latina y el Caribe  América del Sur   266   326   360
# Ecuador    América Latina y el Caribe  América del Sur   238   207   184
# Guyana     América Latina y el Caribe  América del Sur  2334  2943  3575
# Paraguay   América Latina y el Caribe  América del Sur    45    26    32
# Perú       América Latina y el Caribe  América del Sur   317   456   401
# Surinam    América Latina y el Caribe  América del Sur    15    10    21
#
#            1983  1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  \
# Pais                                     ...
# ...

# %%
# Voy a graficar los totales de inmigrantes por país, por medio
# de un gráfico de barras.

colores = ['royalblue', 'orange', 'forestgreen', 'orchid',
           'purple', 'brown', 'slateblue', 'gray', 'olive'
           , 'navy', 'teal', 'tomato']
fig, ax = plt.subplots(figsize = (13, 4))

ax.bar(sudamerica.index, sudamerica['Total'], color = colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\ndurante el período 1980-2013', fontsize = 18, loc = 'left')
ax.set_xlabel('')
ax.set_ylabel('Número de Inmigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

plt.show()

# %%
# Para mejor visualización usamos un gráfico de barras horizontales.

colores = ['royalblue', 'orange', 'forestgreen', 'orchid',
           'purple', 'brown', 'slateblue', 'gray', 'olive'
           , 'navy', 'teal', 'tomato']
fig, ax = plt.subplots(figsize = (13, 4))

ax.barh(sudamerica.index, sudamerica['Total'], color = colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\ndurante el período 1980-2013', fontsize = 18, loc = 'left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

plt.show()

# %%
# Ordenamos las barras para que vayan ascendiendo de menor a mayor, con
# sort_value

sudamerica_sorted = sudamerica.sort_values('Total', ascending = True)

colores = ['royalblue', 'orange', 'forestgreen', 'orchid',
           'purple', 'brown', 'slateblue', 'gray', 'olive'
           , 'navy', 'teal', 'tomato']
fig, ax = plt.subplots(figsize = (13, 4))

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color = colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\ndurante el período 1980-2013', fontsize = 18, loc = 'left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

plt.show()

# %%
 # Vamos a analizar específicamente Colombia.

 colores = []

 for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

fig, ax = plt.subplots(figsize = (13, 4))

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color = colores)
ax.set_title('Sudamérica: Colombia es el segundo país con más migrantes\nhacia Canadá durante el período 1980-2013', fontsize = 16, loc = 'left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize = 13)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

plt.show()

# %%
# Vamos a colocar el valor exacto de migrantes al lado de cada barra.
# Con enumerate.
# j+20 En x el valor de j + 20 pixeles.
# ha = horizontal aligment
# va = vertical aligment
colores = []

for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

fig, ax = plt.subplots(figsize = (13, 4))

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color = colores)
ax.set_title('Sudamérica: Colombia es el segundo país con más migrantes\nhacia Canadá durante el período 1980-2013', fontsize = 16, loc = 'left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize = 13)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

for i,j in enumerate(sudamerica_sorted['Total']):
  ax.text(j+20, i, str(j), color = 'black', fontsize = 8.5, ha = 'left', va = 'center')


plt.show()

# %%
# Para mejor visualización eliminamos el recuadro y el eje x.
# set_frame_on(False)
# set_visible(False)
# Reducimos el tick_params a 0. size = 0

colores = []

for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

fig, ax = plt.subplots(figsize = (13, 4))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis = 'y', which = 'both', size = 0)

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color = colores)
ax.set_title('Sudamérica: Colombia es el segundo país con más migrantes\nhacia Canadá durante el período 1980-2013', fontsize = 16, loc = 'left')
ax.set_ylabel('')
# ax.set_xlabel('Número de Inmigrantes', fontsize = 13)
# ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

for i,j in enumerate(sudamerica_sorted['Total']):
  ax.text(j+20, i, str(j), color = 'black', fontsize = 9, ha = 'left', va = 'center')


plt.show()

# %%
# Exportamos el archivo.
# Verificamos en que formatos lo podemos exportar.
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
# Exportamos el grafico de Colombia. fig.savefig(ruta, transparent = false, dpi = 300,)
# transparent = false Que el fondo del grafico sea blanco y no transparente.
# dpi = resolución del gráfico.
# bbox_inches. Cuanto margen dejamos alrededor del grafico.
# Primero borramos la linea superior y de la derecha. ax.spines['Top'].set_visible(False).
# Quitamos el grid.

fig, ax = plt.subplots(figsize = (8, 4))
ax.plot(df_col['Año'], df_col['Inmigrantes'], lw = 2.5, color = 'g')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigracion de colombianos a Canada\n1980-2013', fontsize = 18, loc = 'left')
ax.set_xlabel('Años', fontsize = 14)
ax.set_ylabel('Numero de Inmigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('/content/inmigrantes_colombianos_canada.png', transparent = False,
            dpi = 300, bbox_inches = 'tight')

plt.show()

# %%
# Exportamos el gráfico con los datos de sudamerica.

colores = []

for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

fig, ax = plt.subplots(figsize = (13, 4))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis = 'y', which = 'both', size = 0)

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color = colores)
ax.set_title('Sudamérica: Colombia es el segundo país con más migrantes\nhacia Canadá durante el período 1980-2013', fontsize = 16, loc = 'left')
ax.set_ylabel('')
# ax.set_xlabel('Número de Inmigrantes', fontsize = 13)
# ax.xaxis.set_tick_params(labelsize = 12)
ax.yaxis.set_tick_params(labelsize = 12)

for i,j in enumerate(sudamerica_sorted['Total']):
  ax.text(j+20, i, str(j), color = 'black', fontsize = 9, ha = 'left', va = 'center')


fig.savefig('/content/inmigrantes_sudamericanos_canada.png', transparent = False,
            dpi = 300, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ### **Seaborn**

# %%
import seaborn as sns

# %%
# Configuramos un theme por default.
sns.set_theme()

# %%
# Vamos a crear un grafico con los datos de inmigración de los países a Canadá.
# Creamos un nuevo df y los datos van a estar en forma descendente.
top_10 = df.sort_values('Total', ascending = False).head(10)
top_10
# Out:
#                        Continente             Region   1980   1981   1982  \
# Pais
# India                        Asia        Sur de Asia   8880   8670   8147
# China                        Asia      Asia Oriental   5123   6682   3308
# Reino Unido                Europa    Norte de Europa  22045  24796  20620
# Filipinas                    Asia   Sudeste Asiático   6051   5921   5249
# Pakistán                     Asia        Sur de Asia    978    972   1201
# Estados Unidos  América del Norte  América del Norte   9378  10030   9074
# Irán                         Asia        Sur de Asia   1172   1429   1822
# Sri Lanka                    Asia        Sur de Asia    185    371    290
# Corea del Sur                Asia      Asia Oriental   1011   1456   1572
# Polonia                    Europa    Europa Oriental    863   2930   5881
#
#                  1983   1984  1985  1986   1987  ...   2005   2006   2007  \
# Pais                                             ...
# ...

# %%
# Creamos el gráfico.

ax = sns.barplot(data = top_10, x = 'Total', y = top_10.index, orient = 'h' )
ax.set(title = 'Número de inmigrantes a Canadá\n1980-2013',
       xlabel = 'Número de inmigrantes', ylabel = 'Año')
plt.show()

# %%
# Para mejorar el gráfico usamos también la biblioteca Matplotlib.

fig, ax = plt.subplots(figsize = (8, 4))

ax = sns.barplot(data = top_10, x = 'Total', y = top_10.index, orient = 'h')
ax.set_title('Número de inmigrantes a Canadá\n1980-2013', loc = 'left', fontsize = 16)
ax.set_xlabel('Número de Inmigrantes')
ax.set_ylabel('')

plt.show()

# %%
# Probando diferentes paletas de colores.
# Generamos una función con el parametro palette para probar
# diferentes paletas.
# Colocamos hue e y para usar correctamente seaborn.

def generar_grafico(palette):
  fig, ax = plt.subplots(figsize = (8, 4))
  ax = sns.barplot(data = top_10, x = 'Total', y = top_10.index, hue = top_10.index, orient = 'h',
                   palette = palette)
  ax.set_title('Número de inmigrantes a Canadá\n1980-2013', loc = 'left', fontsize = 16)
  ax.set_xlabel('Número de Inmigrantes')
  ax.set_ylabel('')

  plt.show()

# %%
# Generamos un gráfico de azules.
# r es por reverse. Para que el país con mayor cantidad de
# inmigrantes se vea más oscuro.

generar_grafico('Blues_r')

# %%
# Quitamos la leyenda con legend = False porque estorba
# en el gráfico.

def generar_grafico(palette):
  fig, ax = plt.subplots(figsize = (8, 4))
  ax.set_frame_on(False)
  # ax.xaxis.set_visible(False)
  # ax.tick_params(axis = 'y', which = 'both', size = 0)
  ax = sns.barplot(data = top_10, x = 'Total', y = top_10.index, hue = top_10.index, orient = 'h',
                   palette = palette, legend = False)
  ax.set_title('Número de inmigrantes a Canadá\n1980-2013', loc = 'left', fontsize = 16)
  ax.set_xlabel('Número de Inmigrantes')
  ax.set_ylabel('')
  for i,j in enumerate(top_10['Total']):
    ax.text(j+20, i, str(j), color = 'black', fontsize = 9, ha = 'left', va = 'center')

  plt.show()

# %%
generar_grafico('Blues_r')

# %%
# Para este ejemplo el mejor tipo de paleta es una categórica.
generar_grafico('Paired')

# %%
generar_grafico('tab10')

# %%
# Cambiamos el frame, xaxis y ticks de Matplotlib por
# Seaborn para no tener conjunción de datos.
# Colocamos xticklabels vacio.
# Quitamos los bordes del gráfico con despine().

def generar_grafico(palette):
  fig, ax = plt.subplots(figsize = (8, 4))
  ax.set(xticklabels = [])
  ax = sns.barplot(data = top_10, x = 'Total', y = top_10.index, hue = top_10.index, orient = 'h',
                   palette = palette, legend = False)
  ax.set_title('Número de inmigrantes a Canadá\n1980-2013', loc = 'left', fontsize = 16)
  ax.set_xlabel('Número de Inmigrantes')
  ax.set_ylabel('')
  sns.despine()
  for i,j in enumerate(top_10['Total']):
    ax.text(j+20, i, str(j), color = 'black', fontsize = 9, ha = 'left', va = 'center')

  plt.show()

# %%
generar_grafico('tab10')

# %%
# Cambiamos el estilo (theme) del gráfico.

sns.set_theme(style = 'whitegrid')
generar_grafico('tab10')

# %%
# Cambiamos el estilo (theme) del gráfico.

sns.set_theme(style = 'white')
generar_grafico('tab10')
